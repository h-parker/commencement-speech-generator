# %% [markdown]
# # What's in this notebook?
# Here I experiment with context free grammars to see use to evaluate markov model sentences (based solely on grammar) and to generate gramatically correct sentences.

# %%
# import speech data
import pickle
import pandas as pd
import numpy as np
from nltk import CFG

with open('labeled_data.pickle', 'rb') as f:
    data = pickle.load(f)

# %% [markdown]
# We can only use gramatically correct transcripts (ie, not YouTube autogenerated text). Thus, we'll get only the punctuated texts by only looking at those with periods and commas.

# %%
cfg_data = data[data.transcript.apply(lambda x: x.count(',') > 1 and x.count('.') > 2)]

# %%
cfg_data
# Out:
#                                                  source  \
# 6           https://www.youtube.com/watch?v=9ZDuNzhelhQ
# 12          https://www.youtube.com/watch?v=RIS2dlnlsRo
# 26          https://www.youtube.com/watch?v=LN2ZlDdaOA8
# 28          https://www.youtube.com/watch?v=WiWLAEY4XK0
# 29          https://www.youtube.com/watch?v=e0SsSr9Trro
# 31          https://www.youtube.com/watch?v=UF8uR6Z6KLc
# 36          https://www.youtube.com/watch?v=28-jRr9MMcY
# 40          https://www.youtube.com/watch?v=4E6ui2HsjjU
# 44          https://www.youtube.com/watch?v=1BVmRt3ap0o
# 45          https://www.youtube.com/watch?v=ZzBCv8VoN3I
# 50          https://www.youtube.com/watch?v=ev3v0bAd1_w
# 73          https://www.youtube.com/watch?v=zPx5N6Lh3sw
# 85          https://www.youtube.com/watch?v=9MOtUvZ-tPc
# 93          https://www.youtube.com/watch?v=V2Jm5v32JBI
# 113         https://www.youtube.com/watch?v=nApD88M0Who
# 118         https://www.youtube.com/watch?v=rBpN8REU0OY
# 148         https://www.youtube.com/watch?v=EKNT_1R3POs
# 154         https://www.youtube.com/watch?v=xOzKPNctR3Y
# 158         https://www.youtube.com/watch?v=dSmruxV5k20
# 163         https://www.youtube.com/watch?v=Cfpq-6tz3To
# 169         https://www.youtube.com/watch?v=qYoZkVL3u5k
# 172         https://www.youtube.com/watch?v=TBuIGBCF9jc
# 175         https://www.youtube.com/watch?v=Qbel5MhtDq4
# 176         https://www.youtube.com/watch?v=EuOm2lLIOoU
# 182         https://www.youtube.com/watch?v=qFb2rvmrahc
# 184         https://www.youtube.com/watch?v=s3F4QU_PaQM
# 191         https://www.youtube.com/watch?v=RwJPOfIQKwA
# 196         https://www.youtube.com/watch?v=IZ4T7P0_MLk
# 205         https://www.youtube.com/watch?v=fsJoPEo142Q
# 208         https://www.youtube.com/watch?v=6wKFQx30f6M
# ...                                                 ...
# 1099  https://www.wellesley.edu/events/commencement/...
# 1100  https://www.wellesley.edu/events/commencement/...
# 1101  https://www.wellesley.edu/events/commencement/...
# 1102  https://www.wellesley.edu/events/commencement/...
# 1103  https://www.wellesley.edu/events/commencement/...
# 1104  https://www.wellesley.edu/events/commencement/...
# 1105  http://www.humanity.org/voices/commencements/m...
# 1106  http://www.humanity.org/voices/commencements/w...
# 1107  http://www.humanity.org/voices/commencements/l...
# 1108  http://www.humanity.org/voices/commencements/r...
# 1109  http://www.humanity.org/voices/commencements/n...
# 1110  http://www.humanity.org/voices/commencements/r...
# 1111  http://www.humanity.org/voices/commencements/v...
# 1112  http://www.humanity.org/voices/commencements/c...
# 1113  http://www.humanity.org/voices/commencements/l...
# 1114  http://www.humanity.org/voices/commencements/m...
# 1115  http://www.humanity.org/voices/commencements/g...
# 1116  http://www.humanity.org/voices/commencements/m...
# 1117  http://www.humanity.org/voices/commencements/u...
# 1118  http://www.humanity.org/voices/commencements/h...
# 1119  http://www.humanity.org/voices/commencements/w...
# 1120  http://www.humanity.org/voices/commencements/t...
# 1121  http://www.humanity.org/voices/commencements/g...
# 1122  http://www.humanity.org/voices/commencements/w...
# 1123     https://www.berklee.edu/commencement/past/1997
# 1124  https://www.berklee.edu/commencement/2000/jsyk...
# 1125  https://www.berklee.edu/commencement/2002/fost...
# 1126          https://www.berklee.edu/commencement/2009
# 1127  https://news.syr.edu/blog/2012/05/13/aaron-sor...
# 1128                   http://gos.sbc.edu/k/khouri.html
#
#                                              transcript  \
# 6     Will the graduates to the degree of Bachelor\n...
# 12    Thank you so  much Thank you. [LAUGHTER] Great...
# 26    [Music] [Music] I'm also pleased to welcome dr...
# 28    >>John Hope Franklin: Chancellor Mullen,\nmemb...
# 29    >> Clifton Wharton: Chancellor Mullen Chairman...
# 31    Thank You. I am honored to be with you today a...
# 36    well we sent an email to all of our faculty st...
# 40    please help me in welcoming to the podium the ...
# 44    [Music] [Music] now it is my pleasure to intro...
# 45    >> Martha Nussbaum: Faculty, administrators,\n...
# 50    it almost goes without saying that we are deep...
# 73    Our next speaker, first known as the entrepren...
# 85    Chancellor Peterson, President Naylor, members...
# 93    >> Earnest Gains: There's no high school\nthat...
# 113   President Bush delivered the commencement addr...
# 118   once again as Jayhawks have done for 136 years...
# 148   this program is brought to you by emory univer...
# 154   so it is fitting that we bring such a fine per...
# 158   thank you that was inspiring and now it is my ...
# 163   I am proud and honored to introduce our commen...
# 169   Thank you very much, dean, it's a great honor ...
# 172   What starts here changes the world I have a fe...
# 175   Now my job is a is a very difficult one.\nHow ...
# 176   Whoa! Well thank you so much and hello UT. And...
# 182   Class of 2009!  I don't think I heard you.\nCl...
# 184   Mr. President, Mr. Chancellor, chair of the\nb...
# 191   (applause and cheering) The President:\nThank ...
# 196   chairman barouche president gray fellow truste...
# 205   On behalf of the faculty of Kalamazoo College\...
# 208   >> Graduates, families, alumni, and honored\ng...
# ...                                                 ...
# 1099  Thank you, Dr. Keohane for that kind introduct...
# 1100  I am honored to share this day with all of the...
# 1101  At the research center where I spent my sabbat...
# 1102  It is a very special pleasure for me to be her...
# 1103  President Keohane, trustees, faculty, students...
# 1104  It's very nice to be here. It seems so familia...
# 1105  President DeGioia, faculty, parents and friend...
# 1106  President Fainstein, Connecticut College trust...
# 1107  If I bear in mind the syllabus with which the ...
# 1108  Members of the class of 1998: In an effort to ...
# 1109  President Walsh, trustees, faculty, friends, n...
# 1110  In a sensible world I would now congratulate t...
# 1111  Mr. President, Mr. Vice-President, ladies and ...
# 1112  Thank you so very much, Professor William Chac...
# 1113  The sportswriter Red Smith was one of my heroe...
# 1114  President Oakley, trustees, faculty, friends a...
# 1115  Mr. President – at last I can say that with pl...
# 1116  I am of course overjoyed to be here today in t...
# 1117  I want to thank the Mills College Class of ‘83...
# 1118  Ever since it was announced that a non-doctor,...
# 1119  Dinner, let us imagine, has reached its second...
# 1120  To the graduating class I address myself to, I...
# 1121  Mr. President, Dr. Conant, members of the Boar...
# 1122  About all that a commencement orator can do fo...
# 1123  I'm very excited right now to be here. It's ki...
# 1124  When I was a kid growing up in Schenectady, Ne...
# 1125  First of all, let me say congratulations to ea...
# 1126  Thank you very much, President [Roger H.] Brow...
# 1127  Thank you very much. Madam Chancellor, members...
# 1128  I'm so happy to be here today. Now, I don't wa...
#
#                                               processed    given_by
# 6     [graduate, degree, bachelor, art, please, rise...   celebrity
# 12    [thank, much, thank, laughter, great, guy, ins...   celebrity
# 26    [music, music, also, please, welcome, dr, elia...   celebrity
# 28    [john, hope, franklin, chancellor, mullen, mem...  politician
# 29    [clifton, wharton, chancellor, mullen, chairma...  politician
# 31    [thank, honor, today, commencementfrom, one, f...  politician
# 36    [well, send, email, faculty, staff, student, g...   celebrity
# 40    [please, help, welcome, podium, man, call, bea...   celebrity
# 44    [music, music, pleasure, introduce, commenceme...    academic
# 45    [martha, nussbaum, faculty, administrator, alu...   celebrity
# 50    [almost, go, without, say, deeply, honor, toda...  politician
# 73    [next, speaker, first, know, entrepreneur, per...    academic
# 85    [chancellor, peterson, president, naylor, memb...  politician
# 93    [earnest, gain, high, school, could, attend, p...  politician
# 113   [president, bush, deliver, commencement, addre...      author
# 118   [jayhawks, do, 136, year, gather, together, ce...    business
# 148   [program, bring, emory, university, dean, thom...  journalist
# 154   [fit, bring, fine, person, personality, dr, wi...     student
# 158   [thank, inspire, pleasure, introduce, commence...   celebrity
# 163   [proud, honor, introduce, commencement, speake...  politician
# 169   [thank, much, dean, great, honor, pleasure, to...   religious
# 172   [start, changes, world, suggestion, may, help,...     faculty
# 175   [job, difficult, one, introduce, person, every...  politician
# 176   [whoa, well, thank, much, hello, ut, want, say...  politician
# 182   [class, year, think, hear, class, year, first,...    academic
# 184   [mr, president, mr, chancellor, chair, board, ...   religious
# 191   [cheer, president, thank, much, thank, notre, ...   religious
# 196   [chairman, barouche, president, gray, fellow, ...   celebrity
# 205   [behalf, faculty, kalamazoo, college, virtue, ...  politician
# 208   [graduates, family, alumnus, honor, guest, gre...    business
# ...                                                 ...         ...
# 1099  [thank, dr, keohane, kind, introduction, glad,...  politician
# 1100  [honor, share, day, class, year, always, remem...  journalist
# 1101  [research, center, spend, sabbatical, year, gr...     faculty
# 1102  [special, pleasure, wellesley, college, today,...      author
# 1103  [president, keohane, trustee, faculty, student...  politician
# 1104  [nice, seem, familiar, froze, whole, time, als...  journalist
# 1105  [president, degioia, faculty, parent, friend, ...    academic
# 1106  [president, fainstein, connecticut, college, t...      author
# 1107  [bear, mind, syllabus, class, year, engage, la...      author
# 1108  [members, class, year, effort, alter, history,...  politician
# 1109  [president, walsh, trustee, faculty, friend, n...  journalist
# 1110  [sensible, world, would, congratulate, class, ...  journalist
# 1111  [mr, president, mr, vice, president, ladie, ge...  politician
# 1112  [thank, much, professor, william, chace, would...    academic
# 1113  [sportswriter, red, smith, one, heroe, long, d...      author
# 1114  [president, oakley, trustee, faculty, friend, ...      author
# 1115  [mr, president, –, last, say, pleasure, –, adm...  journalist
# 1116  [course, overjoyed, today, role, ceremonial, o...      author
# 1117  [want, thank, mills, college, class, ', 83, of...      author
# 1118  [ever, since, announce, non, doctor, fact, act...   celebrity
# 1119  [dinner, let, -PRON-, imagine, reach, second, ...      author
# 1120  [graduate, class, address, want, say, first, m...      author
# 1121  [mr, president, dr, conant, member, board, ove...  politician
# 1122  [commencement, orator, auditor, turn, face, ar...  journalist
# 1123  [excited, right, kind, like, completion, circl...   celebrity
# 1124  [kid, grow, schenectady, new, york, one, thing...   celebrity
# 1125  [first, let, say, congratulation, every, one, ...   celebrity
# 1126  [thank, much, president, roger, h, brown, facu...   celebrity
# 1127  [thank, much, madam, chancellor, members, boar...   celebrity
# 1128  [happy, today, want, worry, look, silly, morta...   celebrity
#
# [499 rows x 4 columns]

# %%
def replace_mult(punc_list, to_replace):
    for punc in punc_list:
        to_replace = to_replace.replace(punc, ' ')
    return to_replace

# %%
take_out = """ HOME   |  CONTACT         (adsbygoogle = window.adsbygoogle ||   ).push({});       HOME   |  CONTACT         (adsbygoogle = window.adsbygoogle ||   ).push({});      HOME   |  CONTACT         (adsbygoogle = window.adsbygoogle ||   ).push({});            (adsbygoogle = window.adsbygoogle ||   ).push({});           (adsbygoogle = window.adsbygoogle ||   ).push({});           """
cfg_data.transcript = cfg_data.transcript.apply(lambda x: 
                          replace_mult(['\n', '\x96', '\x92',
                                        '\x98', '[LAUGHTER]',
                                        '[Applause]', '[Music]',
                                       '>>', '[', ']', ':', 
                                        take_out, '\\', '#', '$',
                                       "'", '(', ')'], x))
# Out:
# /Users/hannah/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %% [markdown]
# ## Part of Speech Tagging
# Need to assign words in the corpora POS tags, so that we can develop a CFG based on that.

# %%
import nltk

cfg_data.transcript.apply(lambda x: 
                          nltk.pos_tag(nltk.word_tokenize(x)))
# Out:
# 6       [(Will, MD), (the, DT), (graduates, NNS), (to,...
# 12      [(Thank, NNP), (you, PRP), (so, RB), (much, JJ...
# 26      [(I, PRP), (m, VBP), (also, RB), (pleased, VBN...
# 28      [(John, NNP), (Hope, NNP), (Franklin, NNP), (C...
# 29      [(Clifton, NNP), (Wharton, NNP), (Chancellor, ...
# 31      [(Thank, NNP), (You, PRP), (., .), (I, PRP), (...
# 36      [(well, RB), (we, PRP), (sent, VBD), (an, DT),...
# 40      [(please, VB), (help, VB), (me, PRP), (in, IN)...
# 44      [(now, RB), (it, PRP), (is, VBZ), (my, PRP$), ...
# 45      [(Martha, NNP), (Nussbaum, NNP), (Faculty, NNP...
# 50      [(it, PRP), (almost, RB), (goes, VBZ), (withou...
# 73      [(Our, PRP$), (next, JJ), (speaker, NN), (,, ,...
# 85      [(Chancellor, NNP), (Peterson, NNP), (,, ,), (...
# 93      [(Earnest, JJS), (Gains, NNS), (There, EX), (s...
# 113     [(President, NNP), (Bush, NNP), (delivered, VB...
# 118     [(once, RB), (again, RB), (as, IN), (Jayhawks,...
# 148     [(this, DT), (program, NN), (is, VBZ), (brough...
# 154     [(so, IN), (it, PRP), (is, VBZ), (fitting, VBG...
# 158     [(thank, NN), (you, PRP), (that, WDT), (was, V...
# 163     [(I, PRP), (am, VBP), (proud, JJ), (and, CC), ...
# 169     [(Thank, NNP), (you, PRP), (very, RB), (much, ...
# 172     [(What, WP), (starts, VBZ), (here, RB), (chang...
# 175     [(Now, RB), (my, PRP$), (job, NN), (is, VBZ), ...
# 176     [(Whoa, NN), (!, .), (Well, NNP), (thank, IN),...
# 182     [(Class, NN), (of, IN), (2009, CD), (!, .), (I...
# 184     [(Mr., NNP), (President, NNP), (,, ,), (Mr., N...
# 191     [(applause, NN), (and, CC), (cheering, VBG), (...
# 196     [(chairman, NN), (barouche, NN), (president, N...
# 205     [(On, IN), (behalf, NN), (of, IN), (the, DT), ...
# 208     [(Graduates, NNS), (,, ,), (families, NNS), (,...
#                               ...
# 1099    [(Thank, NNP), (you, PRP), (,, ,), (Dr., NNP),...
# 1100    [(I, PRP), (am, VBP), (honored, VBN), (to, TO)...
# 1101    [(At, IN), (the, DT), (research, NN), (center,...
# 1102    [(It, PRP), (is, VBZ), (a, DT), (very, RB), (s...
# 1103    [(President, NNP), (Keohane, NNP), (,, ,), (tr...
# 1104    [(It, PRP), (s, VBZ), (very, RB), (nice, JJ), ...
# 1105    [(President, NNP), (DeGioia, NNP), (,, ,), (fa...
# 1106    [(President, NNP), (Fainstein, NNP), (,, ,), (...
# 1107    [(If, IN), (I, PRP), (bear, VBP), (in, IN), (m...
# 1108    [(Members, NNS), (of, IN), (the, DT), (class, ...
# 1109    [(President, NNP), (Walsh, NNP), (,, ,), (trus...
# 1110    [(In, IN), (a, DT), (sensible, JJ), (world, NN...
# 1111    [(Mr., NNP), (President, NNP), (,, ,), (Mr, NN...
# 1112    [(Thank, NNP), (you, PRP), (so, RB), (very, RB...
# 1113    [(The, DT), (sportswriter, NN), (Red, NNP), (S...
# 1114    [(President, NNP), (Oakley, NNP), (,, ,), (tru...
# 1115    [(Mr., NNP), (President, NNP), (–, NNP), (at, ...
# 1116    [(I, PRP), (am, VBP), (of, IN), (course, NN), ...
# 1117    [(I, PRP), (want, VBP), (to, TO), (thank, VB),...
# 1118    [(Ever, RB), (since, IN), (it, PRP), (was, VBD...
# 1119    [(Dinner, NNP), (,, ,), (let, VB), (us, PRP), ...
# 1120    [(To, TO), (the, DT), (graduating, VBG), (clas...
# 1121    [(Mr., NNP), (President, NNP), (,, ,), (Dr., N...
# 1122    [(About, IN), (all, PDT), (that, IN), (a, DT),...
# 1123    [(I, PRP), (m, VBP), (very, RB), (excited, JJ)...
# 1124    [(When, WRB), (I, PRP), (was, VBD), (a, DT), (...
# 1125    [(First, NNP), (of, IN), (all, DT), (,, ,), (l...
# 1126    [(Thank, NNP), (you, PRP), (very, RB), (much, ...
# 1127    [(Thank, NNP), (you, PRP), (very, RB), (much, ...
# 1128    [(I, PRP), (m, VBP), (so, RB), (happy, JJ), (t...
# Name: transcript, Length: 499, dtype: object

# %%
words_with_tags = _

# %%
# get a list of tags for each speech
pos_tag_lists = []
for tup_list in words_with_tags:
    tags = []
    for tup in tup_list:
        tags.append(tup[1])
    pos_tag_lists.append(tags)
pos_tag_lists[55]
# Out:
# ['PRP',
#  'VBZ',
#  'DT',
#  'NN',
#  'CC',
#  'DT',
#  'NN',
#  'TO',
#  'VB',
#  'RB',
#  ',',
#  'PRP',
#  'MD',
#  'VB',
#  'PRP',
#  'IN',
#  'DT',
#  'JJ',
#  'NN',
#  'NNS',
#  'CC',
#  'RB',
#  'NN',
#  'IN',
#  'JJ',
#  'NN',
#  '.',
#  'PRP$',
#  'NN',
#  'IN',
#  'JJ',
#  'JJ',
#  'RB',
#  'JJ',
#  'NNS',
#  'IN',
#  'DT',
#  'NNP',
#  'IN',
#  'NNP',
#  '.',
#  'PRP',
#  'VBD',
#  'JJ',
#  'IN',
#  'DT',
#  'RB',
#  'JJ',
#  'NN',
#  ',',
#  'WRB',
#  'VBZ',
#  'NN',
#  'VB',
#  'TO',
#  'VB',
#  'IN',
#  'NNS',
#  'IN',
#  'NNP',
#  'VBP',
#  'JJR',
#  'IN',
#  'PRP',
#  'VBP',
#  '.',
#  'CC',
#  'PRP',
#  'VBN',
#  ',',
#  'PRP',
#  'VBD',
#  'IN',
#  ',',
#  'CC',
#  'RB',
#  'PRP',
#  'VBZ',
#  'JJ',
#  ',',
#  'NNS',
#  'RB',
#  'VBG',
#  'NNS',
#  'IN',
#  'NNP',
#  ',',
#  'VBP',
#  'IN',
#  'NNS',
#  'IN',
#  'NNP',
#  'VBP',
#  'RBR',
#  '.',
#  'NNS',
#  'IN',
#  'NNP',
#  'VBP',
#  'PRP',
#  'RB',
#  ',',
#  'CC',
#  'JJ',
#  'NNP',
#  'NN',
#  'JJ',
#  ',',
#  'PRP',
#  'VBP',
#  'RB',
#  'RB',
#  'JJ',
#  '.',
#  'CC',
#  'IN',
#  'VBG',
#  'TO',
#  'VB',
#  'WRB',
#  'PRP',
#  'VBZ',
#  'IN',
#  'NN',
#  'VBZ',
#  'IN',
#  'NN',
#  'NN',
#  'WDT',
#  'VBZ',
#  'JJ',
#  'NNS',
#  'RB',
#  ',',
#  'PRP',
#  'VBD',
#  'DT',
#  'NN',
#  ',',
#  'CC',
#  'DT',
#  'NN',
#  'VBZ',
#  'DT',
#  'JJ',
#  'NN',
#  '.',
#  'WRB',
#  'NNS',
#  'VBP',
#  'IN',
#  'NN',
#  'IN',
#  'NNP',
#  'CC',
#  'RB',
#  'IN',
#  'NN',
#  'RB',
#  'IN',
#  'PRP$',
#  'NN',
#  'PRP',
#  'VBZ',
#  'RP',
#  'RB',
#  'NN',
#  'JJ',
#  '.',
#  'PRP',
#  'VBP',
#  'TO',
#  'VB',
#  'IN',
#  'WP',
#  'VBZ',
#  'JJ',
#  ',',
#  'IN',
#  'NN',
#  ',',
#  'IN',
#  'NNP',
#  '.',
#  'RB',
#  'WRB',
#  'NNS',
#  'VBP',
#  'IN',
#  'NNP',
#  ',',
#  'WP',
#  'VBZ',
#  'JJ',
#  'IN',
#  'PRP',
#  'VBP',
#  'IN',
#  'NNP',
#  'CC',
#  'IN',
#  'NNP',
#  'WDT',
#  'VBD',
#  'DT',
#  'NNS',
#  'PRP',
#  'VBN',
#  'NNP',
#  'TO',
#  ',',
#  'PRP',
#  'VBZ',
#  'PDT',
#  'DT',
#  'NN',
#  ',',
#  'CC',
#  'RB',
#  'VB',
#  'PRP',
#  'VB',
#  'PRP',
#  'IN',
#  'PRP',
#  'VBP',
#  'JJ',
#  'NN',
#  'VBP',
#  'PRP',
#  'RB',
#  ',',
#  'DT',
#  'NN',
#  'VBZ',
#  'RBR',
#  'RB',
#  '.',
#  'CC',
#  'RB',
#  'WRB',
#  'PRP',
#  'VBP',
#  'CC',
#  'PRP',
#  'VBP',
#  'IN',
#  'DT',
#  'NN',
#  ',',
#  'PRP',
#  'VBZ',
#  'IN',
#  'IN',
#  'PRP',
#  'VBZ',
#  'JJ',
#  'RB',
#  'JJ',
#  'TO',
#  'VB',
#  'IN',
#  'NNP',
#  'IN',
#  'DT',
#  'NN',
#  'VBZ',
#  'RBR',
#  'RB',
#  ',',
#  'CC',
#  'PRP',
#  'VBZ',
#  'RP',
#  'IN',
#  'DT',
#  'NN',
#  'VBZ',
#  'RB',
#  'JJ',
#  'NN',
#  'TO',
#  'NNS',
#  'NNP',
#  'NN',
#  'NN',
#  '.',
#  'CC',
#  'DT',
#  'NN',
#  'NN',
#  'WDT',
#  'PRP',
#  'VBP',
#  ',',
#  'PRP',
#  'VBP',
#  'PRP',
#  'RB',
#  'RB',
#  'IN',
#  'NNP',
#  ',',
#  'PRP',
#  'VBP',
#  'PRP',
#  'IN',
#  'NN',
#  ',',
#  'NNS',
#  'VBP',
#  'RB',
#  'WRB',
#  'JJ',
#  'NN',
#  'NNS',
#  'TO',
#  'VB',
#  ',',
#  'PRP',
#  'VBZ',
#  'VB',
#  'DT',
#  'JJ',
#  ',',
#  'CC',
#  'PRP',
#  'VBZ',
#  'RB',
#  'JJR',
#  'IN',
#  'NNS',
#  'VBP',
#  'CC',
#  'DT',
#  'JJ',
#  'NN',
#  'MD',
#  'VB',
#  'VBN',
#  'IN',
#  'DT',
#  'NN',
#  'WDT',
#  'MD',
#  'VB',
#  'IN',
#  'JJ',
#  'NN',
#  '.',
#  'NN',
#  'IN',
#  'NN',
#  'VBZ',
#  'RB',
#  'RB',
#  'JJ',
#  'IN',
#  'PRP',
#  'VBP',
#  'PRP',
#  'VBZ',
#  'IN',
#  'PRP',
#  'VBP',
#  'VBG',
#  'IN',
#  'PRP',
#  '.',
#  'CC',
#  'IN',
#  'RB',
#  'VBG',
#  'IN',
#  'NN',
#  'MD',
#  'VB',
#  'PRP',
#  'VB',
#  'PRP$',
#  'NN',
#  'IN',
#  'PRP$',
#  'NN',
#  ',',
#  'CC',
#  'PRP',
#  'VBZ',
#  'RP',
#  'IN',
#  'DT',
#  'VBZ',
#  'RB',
#  'RB',
#  '.',
#  'PRP',
#  'MD',
#  'VB',
#  'TO',
#  'VB',
#  'RB',
#  ',',
#  'IN',
#  'WRB',
#  'PRP',
#  'VBP',
#  'VBG',
#  'IN',
#  'PRP$',
#  'JJ',
#  'CC',
#  'PRP$',
#  'NN',
#  ',',
#  'PRP',
#  'MD',
#  'VB',
#  'IN',
#  'PRP',
#  'VBP',
#  'TO',
#  'VB',
#  'IN',
#  'CD',
#  'NN',
#  'PRP',
#  ',',
#  'CC',
#  'IN',
#  'NN',
#  'IN',
#  'PRP',
#  ',',
#  'EX',
#  'VBP',
#  'CD',
#  'NNS',
#  'IN',
#  'PRP',
#  'MD',
#  'VB',
#  'VBG',
#  'IN',
#  ',',
#  'IN',
#  'WP',
#  'PRP',
#  'VBP',
#  'VBN',
#  'IN',
#  'VBG',
#  'NN',
#  'CC',
#  'IN',
#  'VBG',
#  'NN',
#  ',',
#  'WRB',
#  'NNS',
#  'VBP',
#  'CC',
#  'WRB',
#  'DT',
#  'NN',
#  'VBZ',
#  '.',
#  'IN',
#  'NN',
#  'EX',
#  'VBZ',
#  'DT',
#  'VBG',
#  'NN',
#  'CC',
#  'DT',
#  'VBG',
#  'NN',
#  ',',
#  'CC',
#  'DT',
#  'VBG',
#  'NN',
#  'VBZ',
#  'DT',
#  'CD',
#  ':',
#  'IN',
#  'DT',
#  'NN',
#  'NNS',
#  ',',
#  'WRB',
#  'DT',
#  'NN',
#  'VBZ',
#  'PRP',
#  'WRB',
#  'VB',
#  'PRP',
#  'VB',
#  'RB',
#  ',',
#  'CC',
#  'VBZ',
#  'PRP',
#  'VB',
#  'RB',
#  'WRB',
#  'PRP',
#  'VBP',
#  'PRP',
#  'RB',
#  '.',
#  'PRP',
#  'VBP',
#  'VBG',
#  'IN',
#  'DT',
#  'NN',
#  ',',
#  'IN',
#  'DT',
#  'NN',
#  'IN',
#  'PRP$',
#  'NN',
#  '.',
#  'PRP$',
#  'VBG',
#  'PRP',
#  'VBZ',
#  'IN',
#  'DT',
#  'JJ',
#  ',',
#  'PRP',
#  'VBZ',
#  'NN',
#  '.',
#  'DT',
#  'NNS',
#  'MD',
#  'VB',
#  'RB',
#  'JJ',
#  ',',
#  'PRP',
#  'MD',
#  'VB',
#  'RB',
#  'JJ',
#  'IN',
#  'JJ',
#  'NN',
#  ',',
#  'IN',
#  'JJ',
#  'NN',
#  '.',
#  'DT',
#  'VBG',
#  'NN',
#  'VBZ',
#  'NN',
#  'RB',
#  ',',
#  'DT',
#  'VBG',
#  'NN',
#  'VBZ',
#  'TO',
#  'NN',
#  'IN',
#  'PRP',
#  'MD',
#  'WRB',
#  'PRP',
#  'VBP',
#  'IN',
#  'PRP$',
#  'NN',
#  'CC',
#  'DT',
#  'VBZ',
#  'RB',
#  'NN',
#  'IN',
#  'PRP',
#  'VBP',
#  'DT',
#  'DT',
#  'NN',
#  '.',
#  'RB',
#  ',',
#  'PRP',
#  'VBP',
#  'CC',
#  'PRP',
#  'VBP',
#  'IN',
#  'PRP$',
#  'NN',
#  ',',
#  'CC',
#  'PRP',
#  'VBP',
#  'RB',
#  'CC',
#  'PRP',
#  'VBP',
#  'DT',
#  'NN',
#  'IN',
#  'PRP$',
#  'NN',
#  'CC',
#  'DT',
#  'VBG',
#  'NN',
#  'VBZ',
#  'DT',
#  'NN',
#  ',',
#  'CC',
#  'PRP',
#  'VBZ',
#  'WP',
#  'IN',
#  'JJ',
#  'NNS',
#  'VBZ',
#  'PRP$',
#  'RBS',
#  'JJ',
#  'NN',
#  'WDT',
#  'VBZ',
#  'DT',
#  'NN',
#  'IN',
#  'PRP$',
#  'NN',
#  'IN',
#  'PRP',
#  'VBZ',
#  ',',
#  'PRP',
#  'VBP',
#  'DT',
#  'VBN',
#  'IN',
#  'DT',
#  'NN',
#  'IN',
#  'PRP$',
#  'NN',
#  ',',
#  'PRP',
#  'VBP',
#  'DT',
#  'VBN',
#  'IN',
#  'DT',
#  'NN',
#  'TO',
#  'VB',
#  'DT',
#  'NN',
#  'DT',
#  'JJ',
#  'NN',
#  'IN',
#  'DT',
#  'NN',
#  '.',
#  'PRP',
#  'VBZ',
#  'JJ',
#  'TO',
#  'VB',
#  'IN',
#  'JJ',
#  'RB',
#  'RB',
#  'IN',
#  'NNS',
#  'IN',
#  'DT',
#  'VBG',
#  'NN',
#  'IN',
#  'WRB',
#  'PRP',
#  'VBP',
#  'IN',
#  'PRP$',
#  'NN',
#  ',',
#  'PRP',
#  'VBZ',
#  'VBD',
#  'DT',
#  'JJ',
#  'NN',
#  'WDT',
#  'MD',
#  'VB',
#  'IN',
#  'PRP$',
#  'NN',
#  ',',
#  'DT',
#  'VBG',
#  'NN',
#  'VBZ',
#  'RB',
#  'JJ',
#  'NN',
#  '.',
#  'DT',
#  'VBG',
#  'NN',
#  'VBZ',
#  'WP',
#  'VBZ',
#  'NN',
#  ',',
#  'WRB',
#  'PRP',
#  'VBP',
#  'TO',
#  'VB',
#  'IN',
#  'DT',
#  'JJ',
#  'NN',
#  ',',
#  'PRP',
#  'MD',
#  'VB',
#  'TO',
#  'VB',
#  'IN',
#  'DT',
#  'VBG',
#  'NN',
#  'MD',
#  'RB',
#  'VB',
#  'DT',
#  'JJ',
#  'NN',
#  '.',
#  'CC',
#  'PRP',
#  'VBZ',
#  'RP',
#  'IN',
#  'DT',
#  'VBZ',
#  'RB',
#  'JJ',
#  'IN',
#  'DT',
#  'VBG',
#  'NN',
#  'CC',
#  'DT',
#  'NN',
#  'NN',
#  'VBP',
#  'VBN',
#  'JJ',
#  'TO',
#  'DT',
#  'NN',
#  'IN',
#  'JJ',
#  'NNS',
#  '.',
#  'DT',
#  'VBG',
#  'NN',
#  ',',
#  'WDT',
#  'VBZ',
#  'RB',
#  'DT',
#  'NN',
#  'WDT',
#  'VBZ',
#  'RB',
#  ',',
#  'IN',
#  'VBZ',
#  'DT',
#  'NN',
#  'CC',
#  'VBZ',
#  'DT',
#  'NN',
#  ',',
#  'DT',
#  'VBG',
#  'NN',
#  'VBZ',
#  'VBN',
#  'IN',
#  'WRB',
#  'RB',
#  'PRP',
#  'VBP',
#  ',',
#  'IN',
#  'WRB',
#  'RB',
#  'PRP',
#  'VB',
#  'PRP$',
#  'NNS',
#  '.',
#  'IN',
#  'JJ',
#  'NNS',
#  ',',
#  'PRP',
#  'VBZ',
#  'NNS',
#  'VBN',
#  'IN',
#  'WRB',
#  'JJ',
#  'NN',
#  'PRP',
#  'VBP',
#  'VBG',
#  'CC',
#  'JJ',
#  'NNS',
#  'IN',
#  'NN',
#  '.',
#  'DT',
#  'VBG',
#  'NN',
#  'VBZ',
#  'TO',
#  'VB',
#  'JJ',
#  'IN',
#  'JJ',
#  'NNS',
#  'CC',
#  'PRP',
#  'VBZ',
#  'VBN',
#  'JJ',
#  'RB',
#  'IN',
#  'VBG',
#  'IN',
#  'NNS',
#  ',',
#  'IN',
#  'NN',
#  'NN',
#  'IN',
#  'NNS',
#  'IN',
#  'PRP',
#  'VBP',
#  'CC',
#  'VBP',
#  '.',
#  'DT',
#  'VBZ',
#  'TO',
#  'VB',
#  'DT',
#  'JJ',
#  'NN',
#  'IN',
#  'WP',
#  'PRP',
#  'VBP',
#  'JJ',
#  'NNP',
#  '.',
#  'PRP',
#  'MD',
#  'VB',
#  'VBN',
#  'JJ',
#  'IN',
#  'DT',
#  'NN',
#  'IN',
#  'NNS',
#  ',',
#  'PRP',
#  'MD',
#  'VB',
#  'VBN',
#  'JJ',
#  'IN',
#  'JJ',
#  'NN',
#  ',',
#  'PRP',
#  'MD',
#  'VB',
#  'VBN',
#  'JJ',
#  'IN',
#  'JJ',
#  'NN',
#  ',',
#  'PRP',
#  'MD',
#  'VB',
#  'VBN',
#  'JJ',
#  'IN',
#  'VBG',
#  'JJ',
#  ':',
#  'CC',
#  'RB',
#  'PRP',
#  'VBP',
#  'IN',
#  'WRB',
#  'PRP',
#  'VBP',
#  'IN',
#  'NNS',
#  'WP',
#  'VBP',
#  'DT',
#  'JJR',
#  'JJ',
#  'IN',
#  'NN',
#  ',',
#  'PRP$',
#  'VBG',
#  'NN',
#  'VBZ',
#  'RB',
#  'JJ',
#  'CC',
#  'PRP$',
#  'NN',
#  'NN',
#  'VBZ',
#  'DT',
#  'NN',
#  '.',
#  'RB',
#  ',',
#  'PRP$',
#  'VBG',
#  'NN',
#  'MD',
#  'RB',
#  'VB',
#  'VBN',
#  'JJ',
#  'IN',
#  'VBG',
#  'RB',
#  'JJR',
#  'NN',
#  ',',
#  'CC',
#  'RB',
#  'PRP',
#  'VBP',
#  'VBG',
#  'PRP',
#  'DT',
#  'NN',
#  'IN',
#  'PRP',
#  'VBD',
#  'DT',
#  'NN',
#  '.',
#  'PRP',
#  'VBZ',
#  'RP',
#  'IN',
#  'IN',
#  'DT',
#  'NN',
#  ',',
#  'DT',
#  'JJ',
#  'NN',
#  ...]

# %%
# break up the list of tags into lists of sentences (sentences end in . or ! or ?)
sentences = []
for tag_list in pos_tag_lists:
    sentence = []
    for tag in tag_list:
        if tag != '.':
            sentence.append(tag)
        else:
            sentence.append(tag)
            sentences.append(sentence)
            sentence = []

# %% [markdown]
# ## Turn POS Tags into a CFG
# First, I'll get an idea of the order of these tags, then I'll use then to determine how the CFG will be written.

# %%
# max sentence length
print('max:', max(len(x) for x in sentences))

# min sentence length
print('min:', min(len(x) for x in sentences))

# avg sentence length
print('mean:', np.mean([len(x) for x in sentences]))

# median sentence length
print('median:', np.median([len(x) for x in sentences]))

# avg sentence length
print('1st quartile', np.quantile([len(x) for x in sentences], .25))

# avg sentence length
print('3rd quartile', np.quantile([len(x) for x in sentences], .75))
# Out:
# max: 4706
# min: 1
# mean: 18.088898802159388
# median: 15.0
# 1st quartile 9.0
# 3rd quartile 24.0

# %%
sentence_set = set()
for sentence in sentences:
    # change to a tuple bc lists are unhashable
    sentence_set.add(tuple(sentence))

# this tells us that there are 226,412 types of sentences
len(sentences) - len(sentence_set)
# Out:
# 226412

# %%
# look at the first 10 words
print('first word', {sentence[0] for sentence in sentences if len(sentence) > 0}, '\n')
print('second word', {sentence[1] for sentence in sentences if len(sentence) > 1}, '\n')
print('third word', {sentence[2] for sentence in sentences if len(sentence) > 2}, '\n')
print('fourth word', {sentence[3] for sentence in sentences if len(sentence) > 3}, '\n')
print('fifth word', {sentence[4] for sentence in sentences if len(sentence) > 4}, '\n')
print('sixth word', {sentence[5] for sentence in sentences if len(sentence) > 5}, '\n')
print('seventh word', {sentence[6] for sentence in sentences if len(sentence) > 6}, '\n')
print('eighth word', {sentence[7] for sentence in sentences if len(sentence) > 7}, '\n')
print('nineth word', {sentence[8] for sentence in sentences if len(sentence) > 8}, '\n')
print('tenth word', {sentence[9] for sentence in sentences if len(sentence) > 9}, '\n')
# Out:
# first word {'PRP$', 'UH', '$', ',', 'NNS', 'VBZ', 'JJS', 'PDT', 'EX', 'NNPS', 'RBS', '``', 'RBR', 'IN', 'CD', 'VBD', 'VBN', 'RB', 'MD', 'PRP', '.', 'FW', 'RP', ':', 'NNP', 'VBG', 'NN', 'TO', 'VBP', 'WP', 'WDT', "''", 'JJ', 'VB', 'JJR', 'CC', 'DT', 'WRB'}
#
# second word {'PRP$', 'UH', ',', 'NNS', 'VBZ', 'JJS', 'PDT', 'NNPS', 'EX', 'RBS', '``', 'RBR', 'IN', 'CD', 'VBD', 'VBN', '.', 'PRP', 'RB', 'MD', 'FW', 'RP', ':', 'NNP', 'VBG', 'NN', 'TO', 'VBP', 'WP', 'WDT', "''", 'JJ', 'VB', 'JJR', 'WP$', 'CC', 'DT', 'WRB'}
#
# third word {'PRP$', 'UH', ',', 'NNS', 'VBZ', 'JJS', 'PDT', 'NNPS', 'EX', 'RBS', '``', 'RBR', 'IN', 'VBD', 'CD', 'VBN', '.', 'PRP', 'RB', 'MD', 'FW', 'RP', ':', 'NNP', 'TO', 'NN', 'VBG', 'VBP', 'WP', 'WDT', "''", 'JJ', 'VB', 'JJR', 'WP$', 'CC', 'DT', 'WRB', 'POS'}
#
# fourth word {'PRP$', 'UH', '$', ',', 'NNS', 'VBZ', 'JJS', 'PDT', 'NNPS', 'EX', 'RBS', '``', 'RBR', 'IN', 'CD', 'VBD', 'VBN', '.', 'PRP', 'RB', 'MD', 'FW', 'RP', ':', 'NNP', 'TO', 'NN', 'VBG', 'VBP', 'WP', 'WDT', "''", 'JJ', 'VB', 'JJR', 'WP$', 'CC', 'DT', 'WRB', 'POS'}
#
# fifth word {'PRP$', 'UH', ',', 'NNS', 'VBZ', 'JJS', 'PDT', 'EX', 'NNPS', 'RBS', '``', 'RBR', 'IN', 'VBD', 'CD', 'VBN', 'RB', 'MD', 'PRP', '.', 'FW', 'RP', ':', 'NNP', 'VBG', 'NN', 'TO', 'VBP', 'WP', 'WDT', "''", 'JJ', 'VB', 'JJR', 'WP$', 'CC', 'DT', 'WRB', 'POS'}
#
# sixth word {'PRP$', 'UH', '$', ',', 'NNS', 'VBZ', 'JJS', 'PDT', 'NNPS', 'EX', 'RBS', '``', 'RBR', 'IN', 'VBD', 'CD', 'VBN', 'RB', 'PRP', '.', 'MD', 'FW', 'RP', ':', 'NNP', 'TO', 'NN', 'VBG', 'VBP', 'WP', 'WDT', "''", 'JJ', 'VB', 'JJR', 'WP$', 'CC', 'DT', 'WRB', 'POS'}
#
# seventh word {'PRP$', 'UH', ',', 'NNS', 'VBZ', 'JJS', 'PDT', 'NNPS', 'EX', 'RBS', '``', 'RBR', 'IN', 'VBD', 'CD', 'VBN', 'RB', 'PRP', '.', 'MD', 'FW', 'RP', ':', 'NNP', 'TO', 'NN', 'VBG', 'VBP', 'WP', 'WDT', "''", 'JJ', 'VB', 'JJR', 'WP$', 'CC', 'DT', 'WRB', 'POS'}
#
# eighth word {'SYM', 'PRP$', 'UH', '$', ',', 'NNS', 'VBZ', 'JJS', 'PDT', 'EX', 'NNPS', 'RBS', '``', 'RBR', 'IN', 'VBD', 'CD', 'VBN', 'RB', 'PRP', '.', 'MD', 'FW', 'RP', ':', 'NNP', 'VBG', 'NN', 'TO', 'VBP', 'WP', 'WDT', "''", 'JJ', 'VB', 'JJR', 'WP$', 'CC', 'DT', 'WRB', 'POS'}
#
# nineth word {'PRP$', 'UH', '$', ',', 'NNS', 'VBZ', 'JJS', 'PDT', 'NNPS', 'EX', 'RBS', '``', 'RBR', 'IN', 'VBD', 'CD', 'VBN', 'RB', 'PRP', '.', 'MD', 'FW', 'RP', ':', 'NNP', 'VBG', 'TO', 'NN', 'VBP', 'WP', 'WDT', "''", 'JJ', 'VB', 'JJR', 'WP$', 'CC', 'DT', 'WRB', 'POS'}
#
# tenth word {'PRP$', 'UH', ',', 'NNS', 'VBZ', 'JJS', 'PDT', 'NNPS', 'EX', 'RBS', '``', 'RBR', 'IN', 'VBD', 'CD', 'VBN', 'RB', 'PRP', '.', 'MD', 'FW', 'RP', ':', 'NNP', 'VBG', 'NN', 'TO', 'VBP', 'WP', 'WDT', "''", 'JJ', 'VB', 'JJR', 'WP$', 'CC', 'DT', 'WRB', 'POS'}

# %% [markdown]
# ## Writing a CFG using the NP VP model
# See page 6, Fig 12.3 of http://www.cs.pomona.edu/~kim/CSC181S08/text/12.pdf
# Using this basic structure, I'll begin to write a CFG, then improve that CFG based on examples that are deemed "not proper english". There will likely always be room for improvement, but to begin, I will deem the original transcripts as "proper english", and then get an average score (+1 for each sentence that is deemed proper by the CFG, normalized for the number of sentences in the transcript). That will give me a target score for a "good" speech, which will enable me to compare models.

# %%
# getting some ideas for how certain common sentences are tagged
print(nltk.pos_tag(nltk.word_tokenize('Thank you.')))
print(nltk.pos_tag(nltk.word_tokenize('Congratulations class of 2018.')))
print(nltk.pos_tag(nltk.word_tokenize('I am honored to be here with you all')))
print(nltk.pos_tag(nltk.word_tokenize("If I hadn't done this thing, I wouldn't have gotten where I am today")))
# Out:
# [('Thank', 'NNP'), ('you', 'PRP'), ('.', '.')]
# [('Congratulations', 'NNS'), ('class', 'NN'), ('of', 'IN'), ('2018', 'CD'), ('.', '.')]
# [('I', 'PRP'), ('am', 'VBP'), ('honored', 'VBN'), ('to', 'TO'), ('be', 'VB'), ('here', 'RB'), ('with', 'IN'), ('you', 'PRP'), ('all', 'DT')]
# [('If', 'IN'), ('I', 'PRP'), ('had', 'VBD'), ("n't", 'RB'), ('done', 'VBN'), ('this', 'DT'), ('thing', 'NN'), (',', ','), ('I', 'PRP'), ('would', 'MD'), ("n't", 'RB'), ('have', 'VB'), ('gotten', 'VBN'), ('where', 'WRB'), ('I', 'PRP'), ('am', 'VBP'), ('today', 'NN')]

# %%
# my starting off CFG, based on the link in the markdown cell
cfg_string = """
S -> NP VP 
NP -> Pronoun | ProperNoun | Det Nominal
Pronoun -> 'WP' | 'WP$' | 'PRP' | 'PRP$'
ProperNoun -> 'NNP' | 'NNPS'
Det -> 'CD' | 'DT' | 'WDT' | 'PDT'
Nominal -> 'NN' | 'NNS'
VP -> Verb | Verb NP | Verb NP PP | Verb PP | Verb VP | toVerb | Verb Adverb| '.'
Verb -> 'MD' 'VB' | 'VBD' | 'VBN' | 'VBP' | 'VBZ'
Adverb -> 'RB'
toVerb -> 'TO' Verb
PP -> Preposition NP
Preposition -> 'IN'
"""

# ignore this! I am playing with Stanford's CFG developer (https://web.stanford.edu/class/archive/cs/cs103/cs103.1156/tools/cfg/)
# and it did not like things longer than one character
cfg_alias_string = """
S -> A B
A -> C | D | E | F
C -> 'a' | 'b' | 'c' | 'd'
D -> 'e' | 'f'
E -> 'g' | 'h' | 'i' | 'j'
F -> 'k' | 'l'
B -> G | G A | G A H | G H | G B | I | G J
G -> 'm' 'n' | 'o' | 'p' | 'q' | 'r'
J -> 's'
I -> 't' G
H -> K A
k -> 'u'
"""

# to help me interpret POS tags so that it plays nicely with the alias CFG
pos_alias_dict = {'WP':'a', 'WP$':'b', 'PRP':'c', 'PRP$': 'd', 
'NNP':'e', 'NNPS':'f', 'CD':'g', 'DT': 'h', 
'WDT': 'i', 'PDT':'j', 'NN': 'k', 'NNS': 'l',
'MD': 'm', 'VB':'n', 'VBD':'o', 'VBN':'p', 
'VBP': 'q', 'VBZ':'r', 'RB': 's', 'TO':'t', 
'IN':'u'}

# %%
grammar = CFG.fromstring(cfg_string)
print(grammar)
# Out:
# Grammar with 33 productions (start state = S)
#     S -> NP VP
#     NP -> Pronoun
#     NP -> ProperNoun
#     NP -> Det Nominal
#     Pronoun -> 'WP'
#     Pronoun -> 'WP$'
#     Pronoun -> 'PRP'
#     Pronoun -> 'PRP$'
#     ProperNoun -> 'NNP'
#     ProperNoun -> 'NNPS'
#     Det -> 'CD'
#     Det -> 'DT'
#     Det -> 'WDT'
#     Det -> 'PDT'
#     Nominal -> 'NN'
#     Nominal -> 'NNS'
#     VP -> Verb
#     VP -> Verb NP
#     VP -> Verb NP PP
#     VP -> Verb PP
#     VP -> Verb VP
#     VP -> toVerb
#     VP -> Verb Adverb
#     VP -> '.'
#     Verb -> 'MD' 'VB'
#     Verb -> 'VBD'
#     Verb -> 'VBN'
#     Verb -> 'VBP'
#     Verb -> 'VBZ'
#     Adverb -> 'RB'
#     toVerb -> 'TO' Verb
#     PP -> Preposition NP
#     Preposition -> 'IN'

# %%
rdp = nltk.RecursiveDescentParser(grammar)

# %%
def check_grammar(sentence):
    just_tags = [word_tup[1] for word_tup in nltk.pos_tag(nltk.word_tokenize(sentence))]
    print(rdp.parse(just_tags))
    for tree in rdp.parse(just_tags):
        if len(tree) == 0:
            print('Nope')
        print(tree)
    return

# %%
check_grammar('I will go')
# Out:
# <generator object RecursiveDescentParser._parse at 0x1ab3e507c8>
# (S (NP (Pronoun PRP)) (VP (Verb MD VB)))

# %%
check_grammar('Mary saw a dog')
# Out:
# <generator object RecursiveDescentParser._parse at 0x1ab3e507c8>
# (S (NP (ProperNoun NNP)) (VP (Verb VBD) (NP (Det DT) (Nominal NN))))

# %%
check_grammar('Congratulations to the class of 2018')
# Out:
# <generator object RecursiveDescentParser._parse at 0x1ab7f81e58>

# %% [markdown]
# AAAAAaaaaAAhhHH that's so cool! So far it's only working on basic sentences, but that's a start! Now to try and capture more nuances.
